# %%
s3_bucket_path = "s3://finance-beop-fm/"

files = {
    "orders_raw": "orders_raw.csv",
    "payments_raw": "payments_raw.csv", 
    "expenses_raw": "expenses_raw.csv",
    "budgets_raw": "budgets_raw.csv"
}

print("Listing files in S3 bucket:")
display(dbutils.fs.ls(s3_bucket_path))

bronze_dfs = {}

for table_name, filename in files.items():
    try:
        s3_file_path = f"{s3_bucket_path}{filename}"
        print(f"\n{'-'*65}")
        print(f"Reading {table_name} from: {s3_file_path}")
        print('-'*65)
        
        try:
            df = spark.read \
                .option("header", "true") \
                .option("inferSchema", "true") \
                .option("multiLine", "true") \
                .csv(s3_file_path)
        except Exception as read_error:
            print(f"First read attempt failed: {read_error}")
            print("Trying alternative read method...")
            df = spark.read \
                .option("header", "true") \
                .option("multiLine", "true") \
                .csv(s3_file_path)
        
        from pyspark.sql.functions import current_timestamp, lit
        df = df.withColumn("_ingestion_timestamp", current_timestamp()) \
               .withColumn("_source_file", lit(filename)) \
               .withColumn("_source_path", lit(s3_file_path))
        
        bronze_dfs[table_name] = df
        
        temp_view_name = f"bronze_{table_name}"
        df.createOrReplaceTempView(temp_view_name)
        
        print(f" SUCCESS: {table_name} loaded")
        print(f"   Rows: {df.count():,}")
        print(f"   Columns: {len(df.columns)}")
        print(f"   Temporary View: {temp_view_name}")
        
        print("\n  Sample data:")
        df.show(3, truncate=False)
        
        print("\n  Schema:")
        df.printSchema()
        
    except Exception as e:
        print(f" ERROR loading {table_name}: {str(e)}")
        import traceback
        traceback.print_exc()

print("\n" + "-"*65)
print("BRONZE LAYER SUMMARY")
print("-"*65)
for name, df in bronze_dfs.items():
    print(f"{name}: {df.count():,} rows, {len(df.columns)} columns")

print("\n" + "="*60)
print("AVAILABLE TEMPORARY VIEWS")
print("="*60)
for name in bronze_dfs.keys():
    print(f"bronze_{name}")
    
BRONZE_BASE_PATH = "s3://finance-beop-fm/bronze"

for table_name, df in bronze_dfs.items():
    output_path = f"{BRONZE_BASE_PATH}/{table_name}"
    
    df.write.mode("overwrite").parquet(output_path)
    
    print(f"✅ BRONZE SAVED → {output_path}")
# Out:
# Listing files in S3 bucket:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>s3://finance-beop-fm/budgets_raw.csv</td><td>budgets_raw.csv</td><td>2974</td><td>1767414806000</td></tr><tr><td>s3://finance-beop-fm/expenses_raw.csv</td><td>expenses_raw.csv</td><td>4609</td><td>1767414806000</td></tr><tr><td>s3://finance-beop-fm/orders_raw.csv</td><td>orders_raw.csv</td><td>249339</td><td>1767414808000</td></tr><tr><td>s3://finance-beop-fm/payments_raw.csv</td><td>payments_raw.csv</td><td>359130</td><td>1767414809000</td></tr><tr><td>s3://finance-beop-fm/bronze/</td><td>bronze/</td><td>0</td><td>1767958534602</td></tr></tbody></table></div>
# -----------------------------------------------------------------
# Reading orders_raw from: s3://finance-beop-fm/orders_raw.csv
# -----------------------------------------------------------------
#  SUCCESS: orders_raw loaded
#    Rows: 5,050
#    Columns: 9
#    Temporary View: bronze_orders_raw
#
#   Sample data:
# +--------+----------+-----------+----------------+------------+------------+--------------------------+--------------+-----------------------------------+
# |order_id|order_date|customer_id|product_category|order_amount|order_status|_ingestion_timestamp      |_source_file  |_source_path                       |
# +--------+----------+-----------+----------------+------------+------------+--------------------------+--------------+-----------------------------------+
# |1       |2024-05-09|C8270      |Furniture       |4758.5      |COMPLETED   |2026-01-09 11:35:39.035791|orders_raw.csv|s3://finance-beop-fm/orders_raw.csv|
# |2       |2024-01-12|C6734      |Clothing        |864.37      |COMPLETED   |2026-01-09 11:35:39.035791|orders_raw.csv|s3://finance-beop-fm/orders_raw.csv|
# |3       |2024-05-06|C9322      |Clothing        |376.42      |COMPLETED   |2026-01-09 11:35:39.035791|orders_raw.csv|s3://finance-beop-fm/orders_raw.csv|
# +--------+----------+-----------+----------------+------------+------------+--------------------------+--------------+-----------------------------------+
# only showing top 3 rows
#
#   Schema:
# root
#  |-- order_id: integer (nullable = true)
#  |-- order_date: date (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- product_category: string (nullable = true)
#  |-- order_amount: double (nullable = true)
#  |-- order_status: string (nullable = true)
#  |-- _ingestion_timestamp: timestamp (nullable = false)
#  |-- _source_file: string (nullable = false)
#  |-- _source_path: string (nullable = false)
#
#
# -----------------------------------------------------------------
# Reading payments_raw from: s3://finance-beop-fm/payments_raw.csv
# -----------------------------------------------------------------
#  SUCCESS: payments_raw loaded
#    Rows: 7,521
#    Columns: 9
#    Temporary View: bronze_payments_raw
#
#   Sample data:
# +----------+--------+------------+-----------+--------------+--------------+--------------------------+----------------+-------------------------------------+
# |payment_id|order_id|payment_date|paid_amount|payment_status|payment_method|_ingestion_timestamp      |_source_file    |_source_path                         |
# +----------+--------+------------+-----------+--------------+--------------+--------------------------+----------------+-------------------------------------+
# |P1        |2       |2024-12-14  |279.93     |SUCCESS       |UPI           |2026-01-09 11:35:43.752222|payments_raw.csv|s3://finance-beop-fm/payments_raw.csv|
# |P2        |2       |2025-11-29  |584.44     |SUCCESS       |UPI           |2026-01-09 11:35:43.752222|payments_raw.csv|s3://finance-beop-fm/payments_raw.csv|
# |P3        |3       |2024-06-27  |376.42     |SUCCESS       |BANK_TRANSFER |2026-01-09 11:35:43.752222|payments_raw.csv|s3://finance-beop-fm/payments_raw.csv|
# +----------+--------+------------+-----------+--------------+--------------+--------------------------+----------------+-------------------------------------+
# only showing top 3 rows
#
#   Schema:
# root
#  |-- payment_id: string (nullable = true)
#  |-- order_id: integer (nullable = true)
#  |-- payment_date: date (nullable = true)
#  |-- paid_amount: double (nullable = true)
#  |-- payment_status: string (nullable = true)
#  |-- payment_method: string (nullable = true)
#  |-- _ingestion_timestamp: timestamp (nullable = false)
#  |-- _source_file: string (nullable = false)
#  |-- _source_path: string (nullable = false)
#
#
# -----------------------------------------------------------------
# Reading expenses_raw from: s3://finance-beop-fm/expenses_raw.csv
# -----------------------------------------------------------------
#  SUCCESS: expenses_raw loaded
#    Rows: 120
#    Columns: 8
#    Temporary View: bronze_expenses_raw
#
#   Sample data:
# +----------+----------+------------+----------------+--------------+--------------------------+----------------+-------------------------------------+
# |expense_id|department|expense_date|expense_category|expense_amount|_ingestion_timestamp      |_source_file    |_source_path                         |
# +----------+----------+------------+----------------+--------------+--------------------------+----------------+-------------------------------------+
# |1         |IT        |2024-01-22  |Marketing       |19856.88      |2026-01-09 11:35:47.705576|expenses_raw.csv|s3://finance-beop-fm/expenses_raw.csv|
# |2         |Sales     |2024-01-04  |Utilities       |14952.46      |2026-01-09 11:35:47.705576|expenses_raw.csv|s3://finance-beop-fm/expenses_raw.csv|
# |3         |HR        |2024-01-10  |Salary          |24291.61      |2026-01-09 11:35:47.705576|expenses_raw.csv|s3://finance-beop-fm/expenses_raw.csv|
# +----------+----------+------------+----------------+--------------+--------------------------+----------------+-------------------------------------+
# only showing top 3 rows
#
#   Schema:
# root
#  |-- expense_id: integer (nullable = true)
#  |-- department: string (nullable = true)
#  |-- expense_date: date (nullable = true)
#  |-- expense_category: string (nullable = true)
#  |-- expense_amount: double (nullable = true)
#  |-- _ingestion_timestamp: timestamp (nullable = false)
#  |-- _source_file: string (nullable = false)
#  |-- _source_path: string (nullable = false)
#
#
# -----------------------------------------------------------------
# Reading budgets_raw from: s3://finance-beop-fm/budgets_raw.csv
# -----------------------------------------------------------------
#  SUCCESS: budgets_raw loaded
#    Rows: 120
#    Columns: 6
#    Temporary View: bronze_budgets_raw
#
#   Sample data:
# +----------+----------+-------------+--------------------------+---------------+------------------------------------+
# |department|month     |budget_amount|_ingestion_timestamp      |_source_file   |_source_path                        |
# +----------+----------+-------------+--------------------------+---------------+------------------------------------+
# |IT        |2024-01-01|17767.25     |2026-01-09 11:35:51.285272|budgets_raw.csv|s3://finance-beop-fm/budgets_raw.csv|
# |Sales     |2024-01-01|23151.09     |2026-01-09 11:35:51.285272|budgets_raw.csv|s3://finance-beop-fm/budgets_raw.csv|
# |HR        |2024-01-01|15519.22     |2026-01-09 11:35:51.285272|budgets_raw.csv|s3://finance-beop-fm/budgets_raw.csv|
# +----------+----------+-------------+--------------------------+---------------+------------------------------------+
# only showing top 3 rows
#
#   Schema:
# root
#  |-- department: string (nullable = true)
#  |-- month: date (nullable = true)
#  |-- budget_amount: double (nullable = true)
#  |-- _ingestion_timestamp: timestamp (nullable = false)
#  |-- _source_file: string (nullable = false)
#  |-- _source_path: string (nullable = false)
#
#
# -----------------------------------------------------------------
# BRONZE LAYER SUMMARY
# -----------------------------------------------------------------
# orders_raw: 5,050 rows, 9 columns
# payments_raw: 7,521 rows, 9 columns
# expenses_raw: 120 rows, 8 columns
# budgets_raw: 120 rows, 6 columns
#
# ============================================================
# AVAILABLE TEMPORARY VIEWS
# ============================================================
# bronze_orders_raw
# bronze_payments_raw
# bronze_expenses_raw
# bronze_budgets_raw
# ✅ BRONZE SAVED → s3://finance-beop-fm/bronze/orders_raw
# ✅ BRONZE SAVED → s3://finance-beop-fm/bronze/payments_raw
# ✅ BRONZE SAVED → s3://finance-beop-fm/bronze/expenses_raw
# ✅ BRONZE SAVED → s3://finance-beop-fm/bronze/budgets_raw
